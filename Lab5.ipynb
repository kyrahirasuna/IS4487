# %% [markdown]
# <a href="https://colab.research.google.com/github/kyrahirasuna/IS4487/blob/main/Lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/Twitter_dataset.csv', encoding = 'latin1')

print (df)
# Out:
# Mounted at /content/gdrive
#       Unnamed: 0                       _id                      created_at  \
# 0              0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1              1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2              2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3              3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4              4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# ...          ...                       ...                             ...
# 9751           3  6020fbb89e1aa8e3e7ac0a78  Mon Feb 08 02:01:58 +0000 2021
# 9752           4  6020fbb89e1aa8e3e7ac0a79  Mon Feb 08 01:00:24 +0000 2021
# 9753           5  6020fbb89e1aa8e3e7ac0a7a  Sun Feb 07 23:44:20 +0000 2021
# 9754           6  6020fbb89e1aa8e3e7ac0a7b  Sun Feb 07 23:33:40 +0000 2021
# 9755           7  6020fbb89e1aa8e3e7ac0a7c  Sun Feb 07 23:32:32 +0000 2021
#
# ...

# %%
#look at the top rows
df.head(10)
# Out:
#    Unnamed: 0                       _id                      created_at  \
# 0           0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
# 1           1  6020fc7e9e1aa8e3e7ad0833  Mon Feb 08 04:29:55 +0000 2021
# 2           2  6020fc7e9e1aa8e3e7ad0834  Mon Feb 08 04:29:48 +0000 2021
# 3           3  6020fc7e9e1aa8e3e7ad0835  Mon Feb 08 04:29:43 +0000 2021
# 4           4  6020fc7e9e1aa8e3e7ad0836  Mon Feb 08 04:29:42 +0000 2021
# 5           5  6020fc7e9e1aa8e3e7ad0837  Mon Feb 08 04:29:40 +0000 2021
# 6           6  6020fc7e9e1aa8e3e7ad0838  Mon Feb 08 04:29:40 +0000 2021
# 7           7  6020fc7e9e1aa8e3e7ad0839  Mon Feb 08 04:29:37 +0000 2021
# 8           8  6020fc7e9e1aa8e3e7ad083a  Mon Feb 08 04:29:36 +0000 2021
# 9           9  6020fc7e9e1aa8e3e7ad083b  Mon Feb 08 04:29:35 +0000 2021
#
#              id               id_str  \
# 0  1.358630e+18  1358634152719839233
# 1  1.358630e+18  1358634138639605762
# 2  1.358630e+18  1358634110600826880
# ...

# %%
#look at last rows
df.tail(10)

# %%
#get a summary of the dataset
df.describe()

# %%
#look at the datatypes
df.info()

# %% [markdown]
# ## Clean up the data

# %%
df_clean = df.drop(['display_text_range','truncated','filter_level','matching_rules','_id','id','id_str','in_reply_to_status_id','in_reply_to_status_id_str','in_reply_to_user_id','in_reply_to_user_id_str','geo','coordinates','place','contributors','extended_entities','possibly_sensitive','quoted_status_id','quoted_status_id_str','quoted_status','quoted_status_permalink','scopes'], axis=1)
print(df_clean)
# Out:
#       Unnamed: 0                      created_at  \
# 0              0  Mon Feb 08 04:29:58 +0000 2021
# 1              1  Mon Feb 08 04:29:55 +0000 2021
# 2              2  Mon Feb 08 04:29:48 +0000 2021
# 3              3  Mon Feb 08 04:29:43 +0000 2021
# 4              4  Mon Feb 08 04:29:42 +0000 2021
# ...          ...                             ...
# 9751           3  Mon Feb 08 02:01:58 +0000 2021
# 9752           4  Mon Feb 08 01:00:24 +0000 2021
# 9753           5  Sun Feb 07 23:44:20 +0000 2021
# 9754           6  Sun Feb 07 23:33:40 +0000 2021
# 9755           7  Sun Feb 07 23:32:32 +0000 2021
#
#                                                    text  \
# 0         @Rebe_Charizard ?????????????????????m(*_ _)m
# 1     RT @iiiRatcha: ????????????????????"??????????...
# 2     @kashDAI not you listening to cfm and m&amp;m ...
# 3     RT @_soniashenoy: M&amp;M says \nSsangyong dea...
# 4     RT @mmschocolate: This year?s #SuperBowlLV com...
# ...

# %%
df_clean.head(10)
# Out:
#    Unnamed: 0                      created_at  \
# 0           0  Mon Feb 08 04:29:58 +0000 2021
# 1           1  Mon Feb 08 04:29:55 +0000 2021
# 2           2  Mon Feb 08 04:29:48 +0000 2021
# 3           3  Mon Feb 08 04:29:43 +0000 2021
# 4           4  Mon Feb 08 04:29:42 +0000 2021
# 5           5  Mon Feb 08 04:29:40 +0000 2021
# 6           6  Mon Feb 08 04:29:40 +0000 2021
# 7           7  Mon Feb 08 04:29:37 +0000 2021
# 8           8  Mon Feb 08 04:29:36 +0000 2021
# 9           9  Mon Feb 08 04:29:35 +0000 2021
#
#                                                 text  \
# 0      @Rebe_Charizard ?????????????????????m(*_ _)m
# 1  RT @iiiRatcha: ????????????????????"??????????...
# 2  @kashDAI not you listening to cfm and m&amp;m ...
# 3  RT @_soniashenoy: M&amp;M says \nSsangyong dea...
# 4  RT @mmschocolate: This year?s #SuperBowlLV com...
# 5  RT @Tezhwa: ?????????????????????????????? ???...
# 6  RT @HAIKYUUFESS: *hq contains m/m ushioi // cr...
# ...

# %%
df_clean.drop(columns=df_clean.columns[0], axis=1, inplace=True)

# %%
df_clean_filtered = df_clean[(df_clean['text'].str.contains("M&amp;M?s"))]
df_clean_filtered.head()
# Out:
#                           created_at  \
# 707   Mon Feb 08 03:59:20 +0000 2021
# 3515  Mon Feb 08 02:12:21 +0000 2021
# 4508  Mon Feb 08 01:34:37 +0000 2021
# 6226  Mon Feb 08 00:35:53 +0000 2021
# 7108  Mon Feb 08 00:06:40 +0000 2021
#
#                                                    text  \
# 707   RT @stats_feed: Each package of traditional mi...
# 3515                 M&amp;M Minis &gt; normal M&amp;Ms
# 4508  Hey M&amp;M company, my name is Karen but I?m ...
# 6226  RT @davechensky: Every time i watch an M&amp;M...
# 7108  RT @davechensky: Every time i watch an M&amp;M...
#
#                                                  source  \
# 707   <a href="https://mobile.twitter.com" rel="nofo...
# 3515  <a href="http://twitter.com/download/iphone" r...
# 4508  <a href="http://twitter.com/download/iphone" r...
# 6226  <a href="http://twitter.com/download/android" ...
# 7108  <a href="https://mobile.twitter.com" rel="nofo...
#
#      in_reply_to_screen_name  \
# ...

# %% [markdown]
# ## Graphs

# %%
# Graph language
df_clean_filtered['lang'].value_counts().plot(title ='Language of Tweets', y = 'Count', x='Language', kind='bar')
